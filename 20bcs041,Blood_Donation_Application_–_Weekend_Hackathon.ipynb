# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanya041/chaitanya.dharmireddi_20bcs041_OOPtask1/blob/main/20bcs041%2CBlood_Donation_Application_%E2%80%93_Weekend_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to NGO XYZ\n")
print("please enter your details\n")
print("\n\n REGISTRATION")

admin = "chaitanya"
my_password = "20bcs041"

var1 = input("\nenter a to open admin account b to register:")

if var1 == 'a':
  name = input("\nenter your name:")
  password = input("\nenter your password :")
  if name==admin:
   if password==my_password:
     print("YOUR ADMIN OF XYZ ")
   else:
     print("your password is wrong")
  else:
     print("your not an admin")

elif var1=='b':
   num = int(input("\nenter no. of people came to donate or receive blood:"))
   global dict
   dict = {}
   for i in range(num):

    bloodgroups = ['A+','O+','B+','AB+','A-','O-','B-','AB-']
    
    name = input("\nenter your name:")
    phnum= int(input("\nenter your phone number:"))

    global blood_group
  
    blood_group = input("\nenter your blood group:")

    if blood_group in bloodgroups:
      var2 = input("\nenter d to become a donor and enter r for blood request:")
      if var2=='d':
        if blood_group =='A+':
          print("\nyou can give your blood to A+,AB+")
        elif blood_group =='O+':
          print("\nyou can give your blood to O+,A+,B+,AB+ ")
        elif blood_group =='B+':
          print("\nyou can give your blood to B+,AB+")
        elif blood_group =='AB+':
          print("\nyou can give your blood to AB+ ")
        elif blood_group =='A-':
          print("\nyou can give your blood to A+,A-,AB+,AB- ")
        elif blood_group =='O-':
          print("\nyou can give your blood to EVERYONE ") 
        elif blood_group =='B-':
          print("\nyou can give your blood to B+,B-,AB+,AB-")
        else:
          print("\nyou can give your blood to AB-,AB+")

        print("\nthanks for donating blood\n\n")

      elif var2=='r':
        if blood_group =='A+':
          print("\nyou can receive blood from A+, A-, O-, O+ ")
        elif blood_group =='O+':
          print("\nyou can receive blood from O-, O+")
        elif blood_group =='B+':
          print("\nyou can receive blood from B-, B+, O-, O+")
        elif blood_group =='AB+':
          print("\nyou can receive blood from EVERYONE")
        elif blood_group =='A-':
          print("\nyou can receive blood from A-, O-")
        elif blood_group =='O-':
          print("\nyou can receive blood from O- ") 
        elif blood_group =='B-':
          print("\nyou can receive blood from B-, O- ")
        else:
          print("\nyou can receive blood from AB-, A-, B-, O- \n")

        print("\nyour request was accepted\n ")  
     
     # dict[name]=[blood_group]
      dict.update({name:blood_group})
      print(dict)
      
     


else:
  print("please enter the correct input")


def rarebloodgroups():
 rare_bloodgroups =['AB+','AB-','B-']

 x = dict.values()
 x_list=list(x)
 a = len(x_list)
 for i in range(a):
    if x_list[i] in rare_bloodgroups:

      print('\nrare blood groups are:',x_list[i])
      i = i+1


rarebloodgroups()
# Out:
# welcome to NGO XYZ
#
# please enter your details
#
#
#
#  REGISTRATION
#
# enter a to open admin account b to register:b
#
# enter no. of people came to donate or receive blood:3
#
# enter your name:ram
#
# enter your phone number:23435
#
# enter your blood group:AB-
#
# enter d to become a donor and enter r for blood request:r
#
# you can receive blood from AB-, A-, B-, O-
#
#
# your request was accepted
#
# {'ram': 'AB-'}
#
# enter your name:joe
#
# enter your phone number:556456
#
# enter your blood group:AB+
#
# enter d to become a donor and enter r for blood request:d
#
# you can give your blood to AB+
#
# thanks for donating blood
#
#
# {'ram': 'AB-', 'joe': 'AB+'}
#
# enter your name:ferb
#
# enter your phone number:423542
#
# enter your blood group:O+
#
# enter d to become a donor and enter r for blood request:d
#
# you can give your blood to O+,A+,B+,AB+
#
# thanks for donating blood
#
#
# {'ram': 'AB-', 'joe': 'AB+', 'ferb': 'O+'}
#
# rare blood groups are: AB-
#
# ...
